# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage, SystemMessage
import os

load_dotenv(dotenv_path=r"C:\Users\leksh\Documents\AI_projects\.venv\.env")

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    groq_api_key=os.getenv("GROQ_API_KEY"),
    temperature=0
)

with open("blood_work.txt", "r") as f:
    blood_report = f.read()

print(blood_report[:200])
# Out:
# --------------------------------------------------------------------------
# FileNotFoundError                        Traceback (most recent call last)
# Cell In[6], line 14
#      10     groq_api_key=os.getenv("GROQ_API_KEY"),
#      11     temperature=0
#      12 )
#      13
# ---> 14 with open("blood_work.txt", "r") as f:
#      15     blood_report = f.read()
#      16
#      17 print(blood_report[:200])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'blood_work.txt'
